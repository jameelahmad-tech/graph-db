# %% [markdown]
# # Explor graph name Node and Entity

# %%
import os
import json
import pandas as pd

# === CONFIGURATION ===
JSON_FILE = "sample_graphs.json"
USE_FOLDER = False
FOLDER = "graphs_folder"

def load_graphs_from_folder(folder):
    graphs = {}
    for fname in os.listdir(folder):
        if not fname.endswith(".json"):
            continue
        path = os.path.join(folder, fname)
        with open(path, "r", encoding="utf-8") as f:
            obj = json.load(f)
        for graph_name, data in obj.items():
            graphs[graph_name] = {
                "nodes": data.get("nodes", []),
                "edges": data.get("edges", []),
            }
    return graphs

def load_graph_from_file(json_file):
    with open(json_file, "r", encoding="utf-8") as f:
        obj = json.load(f)
    graphs = {}
    for graph_name, data in obj.items():
        graphs[graph_name] = {
            "nodes": data.get("nodes", []),
            "edges": data.get("edges", []),
        }
    return graphs

def main():
    if USE_FOLDER:
        graphs = load_graphs_from_folder(FOLDER)
    else:
        graphs = load_graph_from_file(JSON_FILE)
    
    if not graphs:
        print("No graphs found.")
        return
    
    for name, data in graphs.items():
        num_nodes = len(data["nodes"])
        num_edges = len(data["edges"])
        print(f"Graph: {name}")
        print(f"  Nodes: {num_nodes}")
        print(f"  Edges: {num_edges}")
        print()

if __name__ == "__main__":
    main()

# %% [markdown]
# # Explor node entity with names

# %%
import os
import json

# === CONFIGURATION ===
JSON_FILE = "sample_graphs.json"
USE_FOLDER = False
FOLDER = "graphs_folder"

def load_graphs_from_folder(folder):
    graphs = {}
    for fname in os.listdir(folder):
        if not fname.endswith(".json"):
            continue
        path = os.path.join(folder, fname)
        with open(path, "r", encoding="utf-8") as f:
            obj = json.load(f)
        for graph_name, data in obj.items():
            graphs[graph_name] = {
                "nodes": data.get("nodes", []),
                "edges": data.get("edges", []),
            }
    return graphs

def load_graph_from_file(json_file):
    with open(json_file, "r", encoding="utf-8") as f:
        obj = json.load(f)
    graphs = {}
    for graph_name, data in obj.items():
        graphs[graph_name] = {
            "nodes": data.get("nodes", []),
            "edges": data.get("edges", []),
        }
    return graphs

def summarize_graph(name, nodes, edges):
    num_nodes = len(nodes)
    num_edges = len(edges)

    # count node labels & names
    label_counts = {}
    name_counts = {}
    for nd in nodes:
        lbl = nd.get("label")
        if lbl is not None:
            label_counts[lbl] = label_counts.get(lbl, 0) + 1
        nm = nd.get("name")
        if nm is not None:
            name_counts[nm] = name_counts.get(nm, 0) + 1

    # count edge types
    rel_counts = {}
    for ed in edges:
        rel = ed.get("type")
        if rel is not None:
            rel_counts[rel] = rel_counts.get(rel, 0) + 1

    # build compact summary line
    parts = [
        f"Graph={name}",
        f"Nodes={num_nodes}",
        f"Edges={num_edges}"
    ]
    if label_counts:
        # pick top 2 labels by count for compactness
        sorted_lbl = sorted(label_counts.items(), key=lambda x: -x[1])
        top_lbl = sorted_lbl[:2]
        lbl_part = "Labels[" + ",".join(f"{lbl}:{cnt}" for lbl, cnt in top_lbl) + "]"
        parts.append(lbl_part)
    if name_counts:
        sorted_nm = sorted(name_counts.items(), key=lambda x: -x[1])
        top_nm = sorted_nm[:2]
        nm_part = "Names[" + ",".join(f"{nm}:{cnt}" for nm, cnt in top_nm) + "]"
        parts.append(nm_part)
    if rel_counts:
        sorted_rel = sorted(rel_counts.items(), key=lambda x: -x[1])
        top_rel = sorted_rel[:2]
        rel_part = "Rels[" + ",".join(f"{r}:{cnt}" for r, cnt in top_rel) + "]"
        parts.append(rel_part)

    return " | ".join(parts)


def main():
    if USE_FOLDER:
        graphs = load_graphs_from_folder(FOLDER)
    else:
        graphs = load_graph_from_file(JSON_FILE)

    if not graphs:
        print("No graphs found.")
        return

    for name, data in graphs.items():
        nodes = data["nodes"]
        edges = data["edges"]
        summary = summarize_graph(name, nodes, edges)
        print(summary)


if __name__ == "__main__":
    main()

# %% [markdown]
# # Remove graph with 0 node and edge

# %%
import json
import os

# === CONFIGURATION ===
INPUT_JSON = "sample_graphs_2nd.json"
OUTPUT_JSON = "clean_graphs_2nd.json"

def load_all_graphs(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        return json.load(f)

def clean_graphs(graphs_dict):
    """
    Given dict: graph_name → { "nodes": [...], "edges": [...] }
    Return new dict with only graphs having nodes>0 or edges>0
    Also return list of removed graph names.
    """
    cleaned = {}
    removed = []
    for name, data in graphs_dict.items():
        nodes = data.get("nodes", [])
        edges = data.get("edges", [])
        if (not nodes) and (not edges):
            removed.append(name)
        else:
            cleaned[name] = data
    return cleaned, removed

def save_graphs(graphs_dict, output_path):
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(graphs_dict, f, indent=2)

def main():
    if not os.path.exists(INPUT_JSON):
        print(f"Input file {INPUT_JSON} not found.")
        return

    all_graphs = load_all_graphs(INPUT_JSON)
    cleaned_graphs, removed = clean_graphs(all_graphs)

    print("Removed graphs (0 nodes & edges):", removed)
    print("Remaining graphs:", list(cleaned_graphs.keys()))

    save_graphs(cleaned_graphs, OUTPUT_JSON)
    print(f"Clean JSON saved as: {OUTPUT_JSON}")

if __name__ == "__main__":
    main()
# Out:
# Removed graphs (0 nodes & edges): ['knowledge_graph', 'playlist_created_spotify', 'last_name_changed', 'yoga_classes_location', 'bedroom_walls_repaint']
# Remaining graphs: ['long_memory_graph', 'degree_graduate', 'long_daily_commute', 'redeem_coupon_coffee', 'play_attend_local']
# Clean JSON saved as: clean_graphs_2nd.json

# %% [markdown]
# # Find Relation btween Node and Edge

# %%
import json

def detect_types(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    # assuming top-level graph name(s)
    for graph_name, g in data.items():
        print("Graph:", graph_name)
        node_labels = set()
        node_types = set()
        node_names = set()
        rel_types = set()
        edges = g.get("edges", [])
        nodes = g.get("nodes", [])

        for nd in nodes:
            lbl = nd.get("label")
            if lbl:
                node_labels.add(lbl)
            typ = nd.get("type")
            if typ:
                node_types.add(typ)
            nm = nd.get("name")
            if nm:
                node_names.add(nm)

        for ed in edges:
            rt = ed.get("type")
            if rt:
                rel_types.add(rt)

        print("  Node labels:", node_labels)
        print("  Node types:", node_types)
        print("  Node names sample:", list(node_names)[:5])
        print("  Relation types:", rel_types)
        print()

if __name__ == "__main__":
    detect_types("clean_graphs_2nd.json")

# %% [markdown]
# # Import data into the database

# %%
import json
import os
from falkordb import FalkorDB
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock

# Configuration

JSON_FILE = "clean_graphs_2nd.json"
HOST = "localhost"
PORT = 6379
BATCH_SIZE = 100
MAX_WORKERS = 4

# Schema definitions
NODE_TYPES = ["Person", "Organization", "Concept", "Event", "Object", "Attribute", "Location"]
NODE_PROPERTIES = ["id", "name", "type", "confidence", "created_at"]
EDGE_PROPERTIES = ["id", "type", "source_id", "target_id", "confidence", "created_at"]

print_lock = Lock()

def safe_print(msg):
    with print_lock:
        print(msg)


# DATA EXTRACTION (Simple & Schema-based)

def get_value(data, key):
    """Get value from data, checking both top-level and properties"""
    # Check top level
    if key in data and data[key] is not None:
        return data[key]
    
    # Check in properties
    if "properties" in data and isinstance(data["properties"], dict):
        if key in data["properties"] and data["properties"][key] is not None:
            return data["properties"][key]
    
    return None

def prepare_node(node):
    """Extract node data according to schema"""
    node_data = {}
    
    # Extract schema-defined properties
    for prop in NODE_PROPERTIES:
        value = get_value(node, prop)
        if value is not None:
            node_data[prop] = value
    
    # Set defaults if missing
    if "name" not in node_data:
        node_data["name"] = "unknown"
    if "type" not in node_data:
        node_data["type"] = "Node"
    
    return node_data

def get_node_label(node):
    """Get node label/type for grouping"""
    label = get_value(node, "label") or get_value(node, "type")
    return label if label else "Node"

def prepare_edge(edge):
    """Extract edge data according to schema"""
    edge_data = {}
    
    # Extract schema-defined properties
    for prop in EDGE_PROPERTIES:
        value = get_value(edge, prop)
        if value is not None:
            edge_data[prop] = value
    
    # Set default type if missing
    if "type" not in edge_data:
        edge_data["type"] = "RELATED_TO"
    
    return edge_data


# BATCH IMPORT FUNCTIONS


def create_batches(items, size):
    """Split list into batches"""
    return [items[i:i + size] for i in range(0, len(items), size)]

def import_node_batch(db, graph_name, label, batch, batch_num, total):
    """Import one batch of nodes"""
    try:
        g = db.select_graph(graph_name)
        
        # Clean label for Cypher
        safe_label = label.replace(" ", "_").replace("-", "_")
        
        # Create Cypher query with UNWIND
        cypher = f"""
        UNWIND $nodes AS node
        CREATE (n:`{safe_label}`)
        SET n.id = node.id,
            n.name = node.name,
            n.type = node.type,
            n.confidence = node.confidence,
            n.created_at = node.created_at
        """
        
        g.query(cypher, {"nodes": batch})
        
        safe_print(f"   [Thread-{batch_num}] ✅ {len(batch)} nodes ({label})")
        return {"success": True, "count": len(batch)}
        
    except Exception as e:
        safe_print(f"   [Thread-{batch_num}] ❌ Error: {e}")
        return {"success": False, "error": str(e)}

def import_edge_batch(db, graph_name, rel_type, batch, batch_num, total):
    """Import one batch of edges"""
    try:
        g = db.select_graph(graph_name)
        
        # Clean relationship type for Cypher
        safe_rel = rel_type.replace(" ", "_").replace("-", "_").upper()
        
        # Create Cypher query with UNWIND
        cypher = f"""
        UNWIND $edges AS edge
        MATCH (source {{id: edge.source_id}})
        MATCH (target {{id: edge.target_id}})
        CREATE (source)-[r:`{safe_rel}`]->(target)
        SET r.id = edge.id,
            r.type = edge.type,
            r.confidence = edge.confidence,
            r.created_at = edge.created_at
        """
        
        g.query(cypher, {"edges": batch})
        
        safe_print(f"   [Thread-{batch_num}] ✅ {len(batch)} edges ({rel_type})")
        return {"success": True, "count": len(batch)}
        
    except Exception as e:
        safe_print(f"   [Thread-{batch_num}] ❌ Error: {e}")
        return {"success": False, "error": str(e)}


# PARALLEL IMPORT


def import_nodes(db, graph_name, nodes):
    """Import all nodes with multi-threading"""
    if not nodes:
        safe_print("   No nodes to import")
        return 0
    
    safe_print(f"\n🔷 IMPORTING NODES")
    
    # Group nodes by label
    nodes_by_label = {}
    skipped = 0
    
    for node in nodes:
        node_data = prepare_node(node)
        
        # Must have ID
        if not node_data.get("id"):
            skipped += 1
            continue
        
        label = get_node_label(node)
        nodes_by_label.setdefault(label, []).append(node_data)
    
    if skipped > 0:
        safe_print(f"   ⚠️  Skipped {skipped} nodes (no ID)")
    
    total_imported = 0
    
    # Import each label type
    for label, node_list in nodes_by_label.items():
        safe_print(f"\n   📊 {label}: {len(node_list)} nodes")
        
        batches = create_batches(node_list, BATCH_SIZE)
        safe_print(f"   📦 {len(batches)} batches")
        
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = [
                executor.submit(import_node_batch, db, graph_name, label, batch, i, len(batches))
                for i, batch in enumerate(batches, 1)
            ]
            
            for future in as_completed(futures):
                result = future.result()
                if result["success"]:
                    total_imported += result["count"]
    
    safe_print(f"\n   ✅ Imported {total_imported} nodes")
    return total_imported

def import_edges(db, graph_name, edges):
    """Import all edges with multi-threading"""
    if not edges:
        safe_print("   No edges to import")
        return 0
    
    safe_print(f"\n🔶 IMPORTING EDGES")
    
    # Group edges by type
    edges_by_type = {}
    skipped = 0
    
    for edge in edges:
        edge_data = prepare_edge(edge)
        
        # Must have source_id and target_id
        if not edge_data.get("source_id") or not edge_data.get("target_id"):
            skipped += 1
            continue
        
        edge_type = edge_data.get("type", "RELATED_TO")
        edges_by_type.setdefault(edge_type, []).append(edge_data)
    
    if skipped > 0:
        safe_print(f"   ⚠️  Skipped {skipped} edges (no source/target)")
    
    total_imported = 0
    
    # Import each relationship type

    for rel_type, edge_list in edges_by_type.items():
        safe_print(f"\n   📊 {rel_type}: {len(edge_list)} edges")
        
        batches = create_batches(edge_list, BATCH_SIZE)
        safe_print(f"   📦 {len(batches)} batches")
        
        with ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
            futures = [
                executor.submit(import_edge_batch, db, graph_name, rel_type, batch, i, len(batches))
                for i, batch in enumerate(batches, 1)
            ]
            
            for future in as_completed(futures):
                result = future.result()
                if result["success"]:
                    total_imported += result["count"]
    
    safe_print(f"\n   ✅ Imported {total_imported} edges")
    return total_imported

# ============================================================================
# VERIFICATION
# ============================================================================

def verify_graph(db, graph_name):
    """Verify import results"""
    safe_print(f"\n🔍 VERIFICATION")
    
    try:
        g = db.select_graph(graph_name)
        
        # Count nodes
        result = g.query("MATCH (n) RETURN count(n) as count")
        nodes = result.result_set[0][0] if result.result_set else 0
        
        # Count edges
        result = g.query("MATCH ()-[r]->() RETURN count(r) as count")
        edges = result.result_set[0][0] if result.result_set else 0
        
        safe_print(f"   📍 Nodes: {nodes}")
        safe_print(f"   🔗 Edges: {edges}")
        
        return nodes, edges
        
    except Exception as e:
        safe_print(f"   ❌ Error: {e}")
        return 0, 0


# MAIN


def main():
    """Main import function"""
    
    print("\n" + "="*70)
    print("🚀 FalkorDB Graph Importer")
    print("="*70)
    print(f"\n📄 File: {JSON_FILE}")
    print(f"🔧 Batch: {BATCH_SIZE} | Workers: {MAX_WORKERS}")
    print(f"🌐 FalkorDB: {HOST}:{PORT}")
    print("\n" + "="*70)
    
    # Check file exists
    if not os.path.exists(JSON_FILE):
        print(f"\n❌ File not found: {JSON_FILE}")
        return
    
    # Load JSON
    print(f"\n📂 Loading data...")
    with open(JSON_FILE, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    print(f"✅ Found {len(data)} graph(s)")
    
    # Connect to FalkorDB
    print(f"🔌 Connecting to FalkorDB...")
    db = FalkorDB(host=HOST, port=PORT)
    print(f"✅ Connected")
    
    # Process each graph
    for graph_name, graph_data in data.items():
        nodes = graph_data.get("nodes", [])
        edges = graph_data.get("edges", [])
        
        print("\n" + "="*70)
        print(f"📊 Graph: {graph_name}")
        print(f"   📍 {len(nodes)} nodes")
        print(f"   🔗 {len(edges)} edges")
        print("="*70)
        
        # Import
        import_nodes(db, graph_name, nodes)
        import_edges(db, graph_name, edges)
        
        # Verify
        verify_graph(db, graph_name)
        
        print(f"\n✅ Graph '{graph_name}' completed")
    
    print("\n" + "="*70)
    print("🎉 ALL DONE!")
    print("="*70 + "\n")

# ============================================================================
# RUN
# ============================================================================

if __name__ == "__main__":
    try:
        main()
    except KeyboardInterrupt:
        print("\n\n⚠️  Stopped by user")
    except Exception as e:
        print(f"\n❌ ERROR: {e}")
        import traceback
        traceback.print_exc()
# Out:
# ======================================================================
# 🚀 FalkorDB Graph Importer
# ======================================================================
#
# 📄 File: clean_graphs_2nd.json
# 🔧 Batch: 100 | Workers: 4
# 🌐 FalkorDB: localhost:6379
#
# ======================================================================
#
# 📂 Loading data...
# ✅ Found 5 graph(s)
# 🔌 Connecting to FalkorDB...
# ✅ Connected
#
# ======================================================================
# 📊 Graph: long_memory_graph
#    📍 3120 nodes
#    🔗 4834 edges
# ======================================================================
#
# 🔷 IMPORTING NODES
#
#    📊 Organization: 195 nodes
#    📦 2 batches
#    [Thread-1] ✅ 100 nodes (Organization)
#    [Thread-2] ✅ 95 nodes (Organization)
#
#    📊 Place: 108 nodes
#    📦 2 batches
#    [Thread-2] ✅ 8 nodes (Place)
#    [Thread-1] ✅ 100 nodes (Place)
#
#    📊 Concept: 2454 nodes
#    📦 25 batches
#    [Thread-1] ✅ 100 nodes (Concept)
#    [Thread-2] ✅ 100 nodes (Concept)
#    [Thread-5] ✅ 100 nodes (Concept)
#    [Thread-6] ✅ 100 nodes (Concept)
#    [Thread-7] ✅ 100 nodes (Concept)
#    [Thread-3] ✅ 100 nodes (Concept)
#    [Thread-4] ✅ 100 nodes (Concept)
#    [Thread-10] ✅ 100 nodes (Concept)
#    [Thread-9] ✅ 100 nodes (Concept)
#    [Thread-11] ✅ 100 nodes (Concept)
#    [Thread-8] ✅ 100 nodes (Concept)
#    [Thread-14] ✅ 100 nodes (Concept)
#    [Thread-12] ✅ 100 nodes (Concept)
#    [Thread-13] ✅ 100 nodes (Concept)
#    [Thread-15] ✅ 100 nodes (Concept)
#    [Thread-16] ✅ 100 nodes (Concept)
#    [Thread-17] ✅ 100 nodes (Concept)
#    [Thread-18] ✅ 100 nodes (Concept)
#    [Thread-19] ✅ 100 nodes (Concept)
#    [Thread-20] ✅ 100 nodes (Concept)
#    [Thread-21] ✅ 100 nodes (Concept)
#    [Thread-22] ✅ 100 nodes (Concept)
#    [Thread-23] ✅ 100 nodes (Concept)
#    [Thread-24] ✅ 100 nodes (Concept)
#    [Thread-25] ✅ 54 nodes (Concept)
#
#    📊 Event: 221 nodes
#    📦 3 batches
#    [Thread-1] ✅ 100 nodes (Event)
#    [Thread-2] ✅ 100 nodes (Event)
#    [Thread-3] ✅ 21 nodes (Event)
#
#    📊 DateTime: 71 nodes
#    📦 1 batches
#    [Thread-1] ✅ 71 nodes (DateTime)
#
#    📊 Person: 71 nodes
#    📦 1 batches
#    [Thread-1] ✅ 71 nodes (Person)
#
#    ✅ Imported 3120 nodes
#
# 🔶 IMPORTING EDGES
#
#    📊 located_in: 48 edges
#    📦 1 batches
#    [Thread-1] ✅ 48 edges (located_in)
#
#    📊 intended_placement_above: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (intended_placement_above)
#
#    📊 intended_for: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (intended_for)
#
#    📊 performs: 1709 edges
#    📦 18 batches
#    [Thread-2] ✅ 100 edges (performs)
#    [Thread-1] ✅ 100 edges (performs)
#    [Thread-3] ✅ 100 edges (performs)
#    [Thread-4] ✅ 100 edges (performs)
#    [Thread-5] ✅ 100 edges (performs)
#    [Thread-6] ✅ 100 edges (performs)
#    [Thread-7] ✅ 100 edges (performs)
#    [Thread-8] ✅ 100 edges (performs)
#    [Thread-9] ✅ 100 edges (performs)
#    [Thread-10] ✅ 100 edges (performs)
#    [Thread-11] ✅ 100 edges (performs)
#    [Thread-12] ✅ 100 edges (performs)
#    [Thread-13] ✅ 100 edges (performs)
#    [Thread-14] ✅ 100 edges (performs)
#    [Thread-15] ✅ 100 edges (performs)
#    [Thread-16] ✅ 100 edges (performs)
#    [Thread-17] ✅ 100 edges (performs)
#    [Thread-18] ✅ 9 edges (performs)
#
#    📊 action_on: 1698 edges
#    📦 17 batches
#    [Thread-1] ✅ 100 edges (action_on)
#    [Thread-2] ✅ 100 edges (action_on)
#    [Thread-3] ✅ 100 edges (action_on)
#    [Thread-4] ✅ 100 edges (action_on)
#    [Thread-5] ✅ 100 edges (action_on)
#    [Thread-6] ✅ 100 edges (action_on)
#    [Thread-7] ✅ 100 edges (action_on)
#    [Thread-8] ✅ 100 edges (action_on)
#    [Thread-9] ✅ 100 edges (action_on)
#    [Thread-10] ✅ 100 edges (action_on)
#    [Thread-11] ✅ 100 edges (action_on)
#    [Thread-12] ✅ 100 edges (action_on)
#    [Thread-13] ✅ 100 edges (action_on)
#    [Thread-14] ✅ 100 edges (action_on)
#    [Thread-15] ✅ 100 edges (action_on)
#    [Thread-16] ✅ 100 edges (action_on)
#    [Thread-17] ✅ 98 edges (action_on)
#
#    📊 would_be_installed_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (would_be_installed_in)
#
#    📊 offers: 27 edges
#    📦 1 batches
#    [Thread-1] ✅ 27 edges (offers)
#
#    📊 sells: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (sells)
#
#    📊 is_budget_option_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_budget_option_from)
#
#    📊 specializes_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (specializes_in)
#
#    📊 includes_spell: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (includes_spell)
#
#    📊 provides_access_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (provides_access_to)
#
#    📊 has_spell: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_spell)
#
#    📊 belongs_to: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (belongs_to)
#
#    📊 helps_improve_survivability_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (helps_improve_survivability_in)
#
#    📊 is_category_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_category_of)
#
#    📊 can_use: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (can_use)
#
#    📊 is_subclass_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_subclass_of)
#
#    📊 uses: 14 edges
#    📦 1 batches
#    [Thread-1] ✅ 14 edges (uses)
#
#    📊 derived_from: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (derived_from)
#
#    📊 is_part_of: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (is_part_of)
#
#    📊 is_rulebook_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_rulebook_for)
#
#    📊 is_calculated_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_calculated_for)
#
#    📊 has_feature: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (has_feature)
#
#    📊 has_ability: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_ability)
#
#    📊 has: 14 edges
#    📦 1 batches
#    [Thread-1] ✅ 14 edges (has)
#
#    📊 is_mechanic_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_mechanic_in)
#
#    📊 require: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (require)
#
#    📊 inhabits: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (inhabits)
#
#    📊 is_milestone_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_milestone_in)
#
#    📊 gained_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (gained_at)
#
#    📊 is_feature_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_feature_of)
#
#    📊 is_class_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_class_in)
#
#    📊 organizes: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (organizes)
#
#    📊 has_spells_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_spells_at)
#
#    📊 can_learn_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (can_learn_from)
#
#    📊 has_attribute: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_attribute)
#
#    📊 involves: 11 edges
#    📦 1 batches
#    [Thread-1] ✅ 11 edges (involves)
#
#    📊 exists_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (exists_in)
#
#    📊 threatens: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (threatens)
#
#    📊 removes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (removes)
#
#    📊 contributes_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (contributes_to)
#
#    📊 produced_by: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (produced_by)
#
#    📊 threaten_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (threaten_in)
#
#    📊 capable_of: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (capable_of)
#
#    📊 guarantees_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (guarantees_for)
#
#    📊 is_type_of: 57 edges
#    📦 1 batches
#    [Thread-1] ✅ 57 edges (is_type_of)
#
#    📊 prioritizes: 21 edges
#    📦 1 batches
#    [Thread-1] ✅ 21 edges (prioritizes)
#
#    📊 categorized_as: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (categorized_as)
#
#    📊 is_variant_of: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (is_variant_of)
#
#    📊 adds_flavor_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (adds_flavor_to)
#
#    📊 occurs_on_schedule: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (occurs_on_schedule)
#
#    📊 occurs_during: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (occurs_during)
#
#    📊 includes: 33 edges
#    📦 1 batches
#    [Thread-1] ✅ 33 edges (includes)
#
#    📊 is_set_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_set_in)
#
#    📊 available_on: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (available_on)
#
#    📊 watched_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (watched_during)
#
#    📊 occurs_on: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (occurs_on)
#
#    📊 should_focus_on: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (should_focus_on)
#
#    📊 requested_from_platform: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (requested_from_platform)
#
#    📊 provides: 12 edges
#    📦 1 batches
#    [Thread-1] ✅ 12 edges (provides)
#
#    📊 criminalizes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (criminalizes)
#
#    📊 enacted_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (enacted_in)
#
#    📊 part_of: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (part_of)
#
#    📊 participated_in: 11 edges
#    📦 1 batches
#    [Thread-1] ✅ 11 edges (participated_in)
#
#    📊 was_colony_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (was_colony_of)
#
#    📊 granted_in_year: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (granted_in_year)
#
#    📊 helps_reduce: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (helps_reduce)
#
#    📊 promotes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (promotes)
#
#    📊 impacts: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (impacts)
#
#    📊 aims_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (aims_for)
#
#    📊 researches: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (researches)
#
#    📊 occurs_before: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (occurs_before)
#
#    📊 pairs_with: 7 edges
#    📦 1 batches
#    [Thread-1] ✅ 7 edges (pairs_with)
#
#    📊 scheduled_for: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (scheduled_for)
#
#    📊 accompanies: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (accompanies)
#
#    📊 marinated_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (marinated_with)
#
#    📊 used_for: 13 edges
#    📦 1 batches
#    [Thread-1] ✅ 13 edges (used_for)
#
#    📊 applied_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (applied_to)
#
#    📊 prepared_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (prepared_for)
#
#    📊 applies_when: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (applies_when)
#
#    📊 require_wake_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (require_wake_time)
#
#    📊 occurs_at: 9 edges
#    📦 1 batches
#    [Thread-1] ✅ 9 edges (occurs_at)
#
#    📊 consumed_during: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (consumed_during)
#
#    📊 renamed_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (renamed_to)
#
#    📊 formerly_known_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (formerly_known_as)
#
#    📊 covers: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (covers)
#
#    📊 offsets: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (offsets)
#
#    📊 stores: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (stores)
#
#    📊 allows_clipping: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (allows_clipping)
#
#    📊 is_example_of: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (is_example_of)
#
#    📊 deposits_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (deposits_to)
#
#    📊 redeems_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (redeems_to)
#
#    📊 are_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (are_for)
#
#    📊 accessed_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (accessed_during)
#
#    📊 stored_on: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (stored_on)
#
#    📊 stored_in: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (stored_in)
#
#    📊 sourced_from: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (sourced_from)
#
#    📊 associated_with: 15 edges
#    📦 1 batches
#    [Thread-1] ✅ 15 edges (associated_with)
#
#    📊 aligns_with: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (aligns_with)
#
#    📊 designed_based_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (designed_based_on)
#
#    📊 supported_by: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (supported_by)
#
#    📊 targets: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (targets)
#
#    📊 based_on: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (based_on)
#
#    📊 relates_to: 14 edges
#    📦 1 batches
#    [Thread-1] ✅ 14 edges (relates_to)
#
#    📊 contains: 15 edges
#    📦 1 batches
#    [Thread-1] ✅ 15 edges (contains)
#
#    📊 used_in: 15 edges
#    📦 1 batches
#    [Thread-1] ✅ 15 edges (used_in)
#
#    📊 informs_strategy_for: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (informs_strategy_for)
#
#    📊 produces: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (produces)
#
#    📊 provides_perspective_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (provides_perspective_for)
#
#    📊 applied_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (applied_in)
#
#    📊 applies_to: 11 edges
#    📦 1 batches
#    [Thread-1] ✅ 11 edges (applies_to)
#
#    📊 has_target_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_target_time)
#
#    📊 applies_framework: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (applies_framework)
#
#    📊 needs_adjustment_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (needs_adjustment_for)
#
#    📊 can_include: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (can_include)
#
#    📊 signals_start_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (signals_start_of)
#
#    📊 has_target_wake_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_target_wake_time)
#
#    📊 has_attempted_wake_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_attempted_wake_time)
#
#    📊 planned_for: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (planned_for)
#
#    📊 leads_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (leads_to)
#
#    📊 scheduled_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (scheduled_on)
#
#    📊 correlates_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (correlates_with)
#
#    📊 located_at: 7 edges
#    📦 1 batches
#    [Thread-1] ✅ 7 edges (located_at)
#
#    📊 helps_establish: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (helps_establish)
#
#    📊 offered_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (offered_to)
#
#    📊 has_not_replied_after: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_not_replied_after)
#
#    📊 take_place_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (take_place_at)
#
#    📊 included_service_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (included_service_for)
#
#    📊 addresses: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (addresses)
#
#    📊 manufactures: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (manufactures)
#
#    📊 has_component: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_component)
#
#    📊 plays_for: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (plays_for)
#
#    📊 competes_in: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (competes_in)
#
#    📊 has_capability: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (has_capability)
#
#    📊 plays_off_strengths_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (plays_off_strengths_of)
#
#    📊 could_trade_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (could_trade_for)
#
#    📊 needs: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (needs)
#
#    📊 have_been_inconsistent_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (have_been_inconsistent_in)
#
#    📊 participates_in: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (participates_in)
#
#    📊 occurred_in: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (occurred_in)
#
#    📊 played_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (played_in)
#
#    📊 performed_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (performed_during)
#
#    📊 competed_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (competed_in)
#
#    📊 exemplifies: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (exemplifies)
#
#    📊 combines: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (combines)
#
#    📊 cuts_through: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (cuts_through)
#
#    📊 complements: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (complements)
#
#    📊 enhances: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (enhances)
#
#    📊 has_characteristic: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_characteristic)
#
#    📊 incorporates_into: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (incorporates_into)
#
#    📊 influences: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (influences)
#
#    📊 informed_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (informed_by)
#
#    📊 held_at: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (held_at)
#
#    📊 performed_at: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (performed_at)
#
#    📊 located_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (located_on)
#
#    📊 features: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (features)
#
#    📊 plays_genre: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (plays_genre)
#
#    📊 is_merchandise_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_merchandise_of)
#
#    📊 is_instance_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_instance_of)
#
#    📊 occurred_at: 9 edges
#    📦 1 batches
#    [Thread-1] ✅ 9 edges (occurred_at)
#
#    📊 feature: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (feature)
#
#    📊 destination_is: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (destination_is)
#
#    📊 took_place_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (took_place_at)
#
#    📊 occurred_at_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (occurred_at_time)
#
#    📊 shows_availability_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (shows_availability_for)
#
#    📊 includes_location: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (includes_location)
#
#    📊 is_signature_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_signature_of)
#
#    📊 told: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (told)
#
#    📊 is_designated_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_designated_as)
#
#    📊 implements_solution: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (implements_solution)
#
#    📊 possesses: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (possesses)
#
#    📊 meets: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (meets)
#
#    📊 uses_ingredient: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (uses_ingredient)
#
#    📊 produce: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (produce)
#
#    📊 includes_locations: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (includes_locations)
#
#    📊 included_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (included_in)
#
#    📊 produced_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (produced_in)
#
#    📊 originates_from: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (originates_from)
#
#    📊 chosen_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (chosen_for)
#
#    📊 proves_ownership_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (proves_ownership_of)
#
#    📊 is_added_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (is_added_to)
#
#    📊 destination_includes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (destination_includes)
#
#    📊 includes_destination: 15 edges
#    📦 1 batches
#    [Thread-1] ✅ 15 edges (includes_destination)
#
#    📊 destination: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (destination)
#
#    📊 added_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (added_to)
#
#    📊 broadcast_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (broadcast_to)
#
#    📊 may_involve: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_involve)
#
#    📊 takes_place_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (takes_place_in)
#
#    📊 involves_finding: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (involves_finding)
#
#    📊 equals_approximately: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (equals_approximately)
#
#    📊 measures_difficulty_of_finding: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (measures_difficulty_of_finding)
#
#    📊 validates_transactions_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (validates_transactions_for)
#
#    📊 validates: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (validates)
#
#    📊 generates: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (generates)
#
#    📊 solves: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (solves)
#
#    📊 requires: 9 edges
#    📦 1 batches
#    [Thread-1] ✅ 9 edges (requires)
#
#    📊 is_verified_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_verified_by)
#
#    📊 solve: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (solve)
#
#    📊 participate_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (participate_in)
#
#    📊 validate: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (validate)
#
#    📊 governs: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (governs)
#
#    📊 defines_reward_mechanism_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (defines_reward_mechanism_for)
#
#    📊 sets: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (sets)
#
#    📊 involves_validating: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (involves_validating)
#
#    📊 adds_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (adds_to)
#
#    📊 maintains: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (maintains)
#
#    📊 verifies: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (verifies)
#
#    📊 represents_difficulty_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (represents_difficulty_of)
#
#    📊 determines_difficulty_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (determines_difficulty_for)
#
#    📊 is_determined_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_determined_by)
#
#    📊 created_through: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created_through)
#
#    📊 is_specified_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_specified_by)
#
#    📊 travels_to: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (travels_to)
#
#    📊 suitable_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (suitable_for)
#
#    📊 offers_activity: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (offers_activity)
#
#    📊 is_suitable_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_suitable_for)
#
#    📊 displayed_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (displayed_using)
#
#    📊 values: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (values)
#
#    📊 includes_participant: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (includes_participant)
#
#    📊 performed_on: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (performed_on)
#
#    📊 dispenses_treats_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (dispenses_treats_for)
#
#    📊 protect: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (protect)
#
#    📊 is_life_stage_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (is_life_stage_of)
#
#    📊 helps_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (helps_with)
#
#    📊 available_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (available_at)
#
#    📊 created_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created_by)
#
#    📊 purchased_from: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (purchased_from)
#
#    📊 has_health_focus_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_health_focus_on)
#
#    📊 experiences: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (experiences)
#
#    📊 used_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (used_on)
#
#    📊 hosts: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (hosts)
#
#    📊 are_featured_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (are_featured_in)
#
#    📊 aired_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (aired_on)
#
#    📊 is_episode_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_episode_of)
#
#    📊 create: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (create)
#
#    📊 focuses_on: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (focuses_on)
#
#    📊 converses_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (converses_with)
#
#    📊 appeared_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (appeared_on)
#
#    📊 is_produced_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_produced_by)
#
#    📊 inspired_action_towards: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (inspired_action_towards)
#
#    📊 opposes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (opposes)
#
#    📊 implemented_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (implemented_using)
#
#    📊 integrates_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (integrates_with)
#
#    📊 works_with: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (works_with)
#
#    📊 appears_in: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (appears_in)
#
#    📊 was_previously: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_previously)
#
#    📊 manages: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (manages)
#
#    📊 results_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (results_from)
#
#    📊 discusses_role_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (discusses_role_of)
#
#    📊 emphasizes_importance_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (emphasizes_importance_for)
#
#    📊 teaches_about: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (teaches_about)
#
#    📊 includes_principles_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (includes_principles_of)
#
#    📊 targets_audience: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (targets_audience)
#
#    📊 is_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_about)
#
#    📊 is_topic_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_topic_for)
#
#    📊 disperses: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (disperses)
#
#    📊 enables: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (enables)
#
#    📊 manufactured_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (manufactured_by)
#
#    📊 performed_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (performed_using)
#
#    📊 reduces: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (reduces)
#
#    📊 occurs_after: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (occurs_after)
#
#    📊 used_after: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (used_after)
#
#    📊 arrived_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (arrived_on)
#
#    📊 measures: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (measures)
#
#    📊 scheduled_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (scheduled_with)
#
#    📊 is_for: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (is_for)
#
#    📊 tracks: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (tracks)
#
#    📊 provides_motivation_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (provides_motivation_for)
#
#    📊 helps_increase: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (helps_increase)
#
#    📊 found_inspiration_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (found_inspiration_on)
#
#    📊 seeks_advice_about: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (seeks_advice_about)
#
#    📊 owns: 15 edges
#    📦 1 batches
#    [Thread-1] ✅ 15 edges (owns)
#
#    📊 asks_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (asks_about)
#
#    📊 prefers: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (prefers)
#
#    📊 inquires_about: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (inquires_about)
#
#    📊 seeks_calculation_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_calculation_for)
#
#    📊 realizes_importance_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (realizes_importance_of)
#
#    📊 engages_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (engages_with)
#
#    📊 interested_in: 19 edges
#    📦 1 batches
#    [Thread-1] ✅ 19 edges (interested_in)
#
#    📊 prefers_texture: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (prefers_texture)
#
#    📊 finds_intriguing: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (finds_intriguing)
#
#    📊 intends_to_try: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (intends_to_try)
#
#    📊 is_interested_in: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (is_interested_in)
#
#    📊 likes: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (likes)
#
#    📊 is_obsessed_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_obsessed_with)
#
#    📊 enjoys: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (enjoys)
#
#    📊 will_use: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (will_use)
#
#    📊 has_heard_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_heard_about)
#
#    📊 values_in_movies: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (values_in_movies)
#
#    📊 has_seen: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_seen)
#
#    📊 uses_platform: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (uses_platform)
#
#    📊 seeks_recommendations_for: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (seeks_recommendations_for)
#
#    📊 plans: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (plans)
#
#    📊 discusses: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (discusses)
#
#    📊 seeks_pairing_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_pairing_for)
#
#    📊 enjoyed: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (enjoyed)
#
#    📊 cooks_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (cooks_for)
#
#    📊 attends: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (attends)
#
#    📊 practices: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (practices)
#
#    📊 prefers_wake_time: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (prefers_wake_time)
#
#    📊 eats: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (eats)
#
#    📊 favors: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (favors)
#
#    📊 plans_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_for)
#
#    📊 is_familiar_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (is_familiar_with)
#
#    📊 plans_to_check_out: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_check_out)
#
#    📊 redeemed_rewards_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (redeemed_rewards_from)
#
#    📊 obtained: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (obtained)
#
#    📊 may_use_morning_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_use_morning_for)
#
#    📊 is_developing: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_developing)
#
#    📊 wakes_up_earlier_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wakes_up_earlier_on)
#
#    📊 wants_to_maintain: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_maintain)
#
#    📊 has_committed_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_committed_to)
#
#    📊 needs_to_clean: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (needs_to_clean)
#
#    📊 considers: 7 edges
#    📦 1 batches
#    [Thread-1] ✅ 7 edges (considers)
#
#    📊 loves: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (loves)
#
#    📊 follows: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (follows)
#
#    📊 watched_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (watched_with)
#
#    📊 has_favorite_moment: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_favorite_moment)
#
#    📊 seeks: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (seeks)
#
#    📊 finds_amazing: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (finds_amazing)
#
#    📊 will_try: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (will_try)
#
#    📊 finds_easier: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (finds_easier)
#
#    📊 examined: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (examined)
#
#    📊 plans_to_start: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_start)
#
#    📊 saw_band_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (saw_band_at)
#
#    📊 considering_visiting: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considering_visiting)
#
#    📊 saw: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (saw)
#
#    📊 attended: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (attended)
#
#    📊 seeks_to_support: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_to_support)
#
#    📊 has_planned: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_planned)
#
#    📊 is_fan_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_fan_of)
#
#    📊 should_visit: 10 edges
#    📦 1 batches
#    [Thread-1] ✅ 10 edges (should_visit)
#
#    📊 intends_to_visit: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (intends_to_visit)
#
#    📊 seeks_to_achieve: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_to_achieve)
#
#    📊 craves: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (craves)
#
#    📊 plans_activity_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_activity_at)
#
#    📊 interested_in_learning_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (interested_in_learning_about)
#
#    📊 can_learn_at: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (can_learn_at)
#
#    📊 wants_to_taste: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_taste)
#
#    📊 plans_to_add_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_add_to)
#
#    📊 wants_to_try: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (wants_to_try)
#
#    📊 interested_in_visiting: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (interested_in_visiting)
#
#    📊 plans_trip_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_trip_to)
#
#    📊 questions_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (questions_about)
#
#    📊 wants_to_learn_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_learn_about)
#
#    📊 wishes_to_join: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (wishes_to_join)
#
#    📊 considers_getting: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considers_getting)
#
#    📊 considers_purchasing_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considers_purchasing_from)
#
#    📊 seeks_recommendation_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_recommendation_for)
#
#    📊 plans_activity_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_activity_with)
#
#    📊 recalls: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (recalls)
#
#    📊 satisfied_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (satisfied_with)
#
#    📊 listened_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (listened_on)
#
#    📊 listens_to: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (listens_to)
#
#    📊 stays_informed_via: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (stays_informed_via)
#
#    📊 considers_starting: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considers_starting)
#
#    📊 created: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created)
#
#    📊 creates: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (creates)
#
#    📊 plans_class_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_class_about)
#
#    📊 requests_texts_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (requests_texts_for)
#
#    📊 requests_planning_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (requests_planning_of)
#
#    📊 pursues: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (pursues)
#
#    📊 aims_to_maintain: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (aims_to_maintain)
#
#    📊 schedules: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (schedules)
#
#    📊 wants_to_increase: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_increase)
#
#    📊 can_search_routes_using: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (can_search_routes_using)
#
#    📊 prepares_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (prepares_for)
#
#    📊 considers_troubleshooting: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considers_troubleshooting)
#
#    📊 will_perform: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (will_perform)
#
#    📊 seeks_apps_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_apps_for)
#
#    📊 includes_in_conversations: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (includes_in_conversations)
#
#    📊 runs_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (runs_on)
#
#    📊 has_relationship_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_relationship_with)
#
#    📊 wants_to_practice: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_practice)
#
#    📊 requests_information_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (requests_information_about)
#
#    📊 lives_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (lives_with)
#
#    📊 lives_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (lives_in)
#
#    📊 chose: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (chose)
#
#    📊 reflects_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (reflects_on)
#
#    📊 shares_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (shares_with)
#
#    📊 will_track: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (will_track)
#
#    📊 wants_to_track: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_track)
#
#    📊 communicates_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (communicates_to)
#
#    📊 affiliated_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (affiliated_with)
#
#    📊 seeks_feedback_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_feedback_on)
#
#    📊 seeks_transparency_with: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (seeks_transparency_with)
#
#    📊 expresses_concern_about: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (expresses_concern_about)
#
#    📊 questions: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (questions)
#
#    📊 undertakes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (undertakes)
#
#    📊 consumes_before: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (consumes_before)
#
#    📊 has_role: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_role)
#
#    📊 seeks_motivation_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_motivation_for)
#
#    📊 took_break_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (took_break_from)
#
#    📊 learned_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (learned_about)
#
#    📊 planning: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (planning)
#
#    📊 plans_to_serve: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (plans_to_serve)
#
#    📊 seeks_ideas_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (seeks_ideas_for)
#
#    📊 plans_to_contact: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_contact)
#
#    📊 is_best_friend_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_best_friend_of)
#
#    📊 plans_to_collaborate_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_collaborate_on)
#
#    📊 operates: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (operates)
#
#    📊 wants_to_improve: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_improve)
#
#    📊 needs_to_restock: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (needs_to_restock)
#
#    📊 likes_idea_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (likes_idea_of)
#
#    📊 wants_gift_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_gift_for)
#
#    📊 has_passion_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_passion_for)
#
#    📊 chose_design_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (chose_design_for)
#
#    📊 related_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (related_to)
#
#    📊 adds_to_list: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (adds_to_list)
#
#    📊 will_attend: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (will_attend)
#
#    📊 is_involved_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_involved_in)
#
#    📊 works_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (works_in)
#
#    📊 completed: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (completed)
#
#    📊 seeks_advice_on: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (seeks_advice_on)
#
#    📊 visits_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (visits_with)
#
#    📊 tracks_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (tracks_using)
#
#    📊 aims_to_improve: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (aims_to_improve)
#
#    📊 wants_to_prevent: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_prevent)
#
#    📊 wants_to_photograph: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_photograph)
#
#    📊 seeks_to_prevent: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_to_prevent)
#
#    📊 transitions_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (transitions_from)
#
#    📊 seeks_to_organize: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_to_organize)
#
#    📊 graduated_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (graduated_with)
#
#    📊 plans_to_track: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_track)
#
#    📊 plans_to_implement: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_implement)
#
#    📊 wants_to_manage: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_manage)
#
#    📊 has_degree_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_degree_in)
#
#    📊 transitions_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (transitions_to)
#
#    📊 plans_to_try: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (plans_to_try)
#
#    📊 wants_to_clean: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (wants_to_clean)
#
#    📊 wants_to_save_money_on: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (wants_to_save_money_on)
#
#    📊 seeks_to_streamline: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_to_streamline)
#
#    📊 engages_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (engages_in)
#
#    📊 seeks_ideas_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (seeks_ideas_about)
#
#    📊 serves_as_starting_point_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (serves_as_starting_point_for)
#
#    📊 can_replace_bulbs_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (can_replace_bulbs_in)
#
#    📊 same_as: 8 edges
#    📦 1 batches
#    [Thread-1] ✅ 8 edges (same_as)
#
#    📊 used_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (used_during)
#
#    📊 will_be_used_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (will_be_used_for)
#
#    📊 monitors: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (monitors)
#
#    📊 provides_courses_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (provides_courses_on)
#
#    📊 sent_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (sent_to)
#
#    📊 does_not_explicitly_mention: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (does_not_explicitly_mention)
#
#    📊 addresses_transfers_from: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (addresses_transfers_from)
#
#    📊 occur_during: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (occur_during)
#
#    📊 is_practice_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_practice_of)
#
#    📊 regulates: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (regulates)
#
#    📊 encompasses: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (encompasses)
#
#    📊 prompted_reflection_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (prompted_reflection_about)
#
#    📊 covers_topic: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (covers_topic)
#
#    📊 exists_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (exists_at)
#
#    📊 works_within: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (works_within)
#
#    📊 measured_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (measured_in)
#
#    📊 implements: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (implements)
#
#    📊 communicated_to: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (communicated_to)
#
#    📊 conveys: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (conveys)
#
#    📊 contributed_to_shaping: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (contributed_to_shaping)
#
#    📊 shapes: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (shapes)
#
#    📊 shaped_identity_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (shaped_identity_of)
#
#    📊 created_mythology_around: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created_mythology_around)
#
#    📊 had_role_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (had_role_in)
#
#    📊 occurred_during: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (occurred_during)
#
#    📊 was_disaster_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_disaster_for)
#
#    📊 led: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (led)
#
#    📊 observed_by: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (observed_by)
#
#    📊 affected: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (affected)
#
#    📊 affects: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (affects)
#
#    📊 contrasted_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (contrasted_with)
#
#    📊 occurs_in: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (occurs_in)
#
#    📊 causes: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (causes)
#
#    📊 should_take_action_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (should_take_action_on)
#
#    📊 occur_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (occur_in)
#
#    📊 potential_addition_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (potential_addition_to)
#
#    📊 published_report_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (published_report_on)
#
#    📊 consumed_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (consumed_with)
#
#    📊 delivers: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (delivers)
#
#    📊 have: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (have)
#
#    📊 communicate_through: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (communicate_through)
#
#    📊 are_example_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (are_example_of)
#
#    📊 was_conducted_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_conducted_for)
#
#    📊 improved: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (improved)
#
#    📊 involved: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (involved)
#
#    📊 investigated: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (investigated)
#
#    📊 informed_creation_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (informed_creation_of)
#
#    📊 created_for: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (created_for)
#
#    📊 created_using: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (created_using)
#
#    📊 evaluated: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (evaluated)
#
#    📊 conducted_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (conducted_for)
#
#    📊 validated: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (validated)
#
#    📊 connects_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (connects_to)
#
#    📊 improved_by: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (improved_by)
#
#    📊 marks_territory_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (marks_territory_with)
#
#    📊 redesigned: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (redesigned)
#
#    📊 use_for_communication: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (use_for_communication)
#
#    📊 communicate_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (communicate_using)
#
#    📊 live_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (live_in)
#
#    📊 used_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (used_with)
#
#    📊 may_feature: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (may_feature)
#
#    📊 served_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (served_at)
#
#    📊 considered_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (considered_for)
#
#    📊 may_have_information_about: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_have_information_about)
#
#    📊 has_information_about: 5 edges
#    📦 1 batches
#    [Thread-1] ✅ 5 edges (has_information_about)
#
#    📊 sold_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (sold_at)
#
#    📊 features_wines_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (features_wines_from)
#
#    📊 featured_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (featured_at)
#
#    📊 involved_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (involved_in)
#
#    📊 hosted: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (hosted)
#
#    📊 formatted_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (formatted_as)
#
#    📊 identifies_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (identifies_as)
#
#    📊 may_provide_info_about: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_provide_info_about)
#
#    📊 provides_resources_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (provides_resources_for)
#
#    📊 may_know_about: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_know_about)
#
#    📊 position_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (position_at)
#
#    📊 requires_skills_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (requires_skills_in)
#
#    📊 may_carry: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (may_carry)
#
#    📊 mentioned_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (mentioned_in)
#
#    📊 helps_improve: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (helps_improve)
#
#    📊 may_help_improve: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_help_improve)
#
#    📊 feels_right_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (feels_right_for)
#
#    📊 is_child_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (is_child_of)
#
#    📊 is_recipient_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_recipient_of)
#
#    📊 hosted_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (hosted_for)
#
#    📊 celebrates: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (celebrates)
#
#    📊 is_mother_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_mother_of)
#
#    📊 is_gift_for: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (is_gift_for)
#
#    📊 may_include: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (may_include)
#
#    📊 given_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (given_at)
#
#    📊 occurred_on: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (occurred_on)
#
# ...
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (streamlines)
#
#    📊 ideal_for: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (ideal_for)
#
#    📊 will_be_placed_on: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (will_be_placed_on)
#
#    📊 selected_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (selected_for)
#
#    📊 is_played_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_played_during)
#
#    📊 explores: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (explores)
#
#    📊 helps_simplify: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (helps_simplify)
#
#    📊 explores_connection_between: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (explores_connection_between)
#
#    📊 plays: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (plays)
#
#    📊 hosted_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (hosted_at)
#
#    📊 facilitated_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (facilitated_by)
#
#    📊 assists_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (assists_during)
#
#    📊 responds_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (responds_to)
#
#    📊 maintains_alongside: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (maintains_alongside)
#
#    📊 dates_back_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (dates_back_to)
#
#    📊 has_units_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_units_in)
#
#    📊 received_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (received_from)
#
#    📊 was_located_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_located_in)
#
#    📊 occur_in: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (occur_in)
#
#    📊 makes_inviting_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (makes_inviting_for)
#
#    📊 makes_comfortable_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (makes_comfortable_for)
#
#    📊 oversees: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (oversees)
#
#    📊 related_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (related_to)
#
#    📊 also_known_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (also_known_as)
#
#    📊 fights_against: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (fights_against)
#
#    📊 has_deadline: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (has_deadline)
#
#    📊 researches: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (researches)
#
#    📊 received: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (received)
#
#    📊 earned_undergraduate_degree_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (earned_undergraduate_degree_from)
#
#    📊 earned_medical_degree_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (earned_medical_degree_from)
#
#    📊 is_board_certified_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_board_certified_in)
#
#    📊 replaces: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (replaces)
#
#    📊 raises_awareness_about: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (raises_awareness_about)
#
#    📊 introduced_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (introduced_in)
#
#    📊 regulate: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (regulate)
#
#    📊 focuses_on_population: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (focuses_on_population)
#
#    📊 studied_within: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (studied_within)
#
#    📊 awarded_by: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (awarded_by)
#
#    📊 is_professor_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_professor_at)
#
#    📊 is_expert_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_expert_in)
#
#    📊 completed_degree_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (completed_degree_at)
#
#    📊 honors: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (honors)
#
#    📊 launched_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (launched_by)
#
#    📊 honored_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (honored_by)
#
#    📊 was_known_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_known_for)
#
#    📊 supported: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (supported)
#
#    📊 published_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (published_by)
#
#    📊 made_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (made_by)
#
#    📊 enhances: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (enhances)
#
#    📊 tests: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (tests)
#
#    📊 established: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (established)
#
#    📊 founded_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (founded_in)
#
#    📊 includes_supporting: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (includes_supporting)
#
#    📊 recognizes_achievement_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (recognizes_achievement_in)
#
#    📊 completed_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (completed_at)
#
#    📊 created_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created_in)
#
#    📊 passes_through: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (passes_through)
#
#    📊 was_key_figure_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_key_figure_in)
#
#    📊 served_as_advisor_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (served_as_advisor_to)
#
#    📊 was_fluent_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (was_fluent_in)
#
#    📊 is_significant_figure_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_significant_figure_in)
#
#    📊 was_part_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_part_of)
#
#    📊 was_conquistador_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_conquistador_in)
#
#    📊 is_language_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_language_of)
#
#    📊 may_inspire: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (may_inspire)
#
#    📊 leads_transition_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (leads_transition_to)
#
#    📊 relates_to_reduction_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (relates_to_reduction_of)
#
#    📊 adopts: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (adopts)
#
#    📊 encourages_use_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (encourages_use_of)
#
#    📊 promoted_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (promoted_at)
#
#    📊 involved: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (involved)
#
#    📊 is_suitable_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_suitable_for)
#
#    📊 improves: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (improves)
#
#    📊 help_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (help_with)
#
#    📊 causes_delay_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (causes_delay_of)
#
#    📊 helps_maintain: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (helps_maintain)
#
#    📊 topped_with: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (topped_with)
#
#    📊 consists_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (consists_of)
#
#    📊 perform: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (perform)
#
#    📊 report_on: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (report_on)
#
#    📊 should_avoid: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (should_avoid)
#
#    📊 should_portray_accurately: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (should_portray_accurately)
#
#    📊 should_be_aware_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (should_be_aware_of)
#
#    📊 reports_on: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (reports_on)
#
#    📊 commits_to: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (commits_to)
#
#    📊 avoid_relying_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (avoid_relying_on)
#
#    📊 research: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (research)
#
#    📊 characterized_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (characterized_by)
#
#    📊 encompasses: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (encompasses)
#
#    📊 enables_accurate_reporting_of: 4 edges
#    📦 1 batches
#    [Thread-1] ✅ 4 edges (enables_accurate_reporting_of)
#
#    📊 can_be: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (can_be)
#
#    📊 should_shift_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (should_shift_from)
#
#    📊 should_shift_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (should_shift_to)
#
#    📊 planned_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (planned_for)
#
#    📊 uses_frontend: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (uses_frontend)
#
#    📊 deployed_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (deployed_using)
#
#    📊 built_using: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (built_using)
#
#    📊 work_on: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (work_on)
#
#    📊 serves: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (serves)
#
#    📊 follows_methodology: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (follows_methodology)
#
#    📊 staffed_with: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (staffed_with)
#
#    📊 potential_topic_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (potential_topic_for)
#
#    📊 stores: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (stores)
#
#    📊 stores_data_for: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (stores_data_for)
#
#    📊 validates: 12 edges
#    📦 1 batches
#    [Thread-1] ✅ 12 edges (validates)
#
#    📊 evaluates: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (evaluates)
#
#    📊 documents: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (documents)
#
#    📊 meets: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (meets)
#
#    📊 referenced_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (referenced_in)
#
#    📊 recorded_in: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (recorded_in)
#
#    📊 described_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (described_in)
#
#    📊 records_miracles_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (records_miracles_of)
#
#    📊 exposes_functionality_via: 6 edges
#    📦 1 batches
#    [Thread-1] ✅ 6 edges (exposes_functionality_via)
#
#    📊 uses_language: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (uses_language)
#
#    📊 handles_integration_with: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (handles_integration_with)
#
#    📊 connects_to: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (connects_to)
#
#    📊 works_with_data_from: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (works_with_data_from)
#
#    📊 driven_by: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (driven_by)
#
#    📊 deliver: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (deliver)
#
#    📊 works_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (works_in)
#
#    📊 affected_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (affected_by)
#
#    📊 accommodates: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (accommodates)
#
#    📊 hosted_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (hosted_in)
#
#    📊 have: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (have)
#
#    📊 showcases: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (showcases)
#
#    📊 hosted: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (hosted)
#
#    📊 is_variant_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_variant_of)
#
#    📊 uses_connection_type: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (uses_connection_type)
#
#    📊 monitors: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (monitors)
#
#    📊 configured_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (configured_using)
#
#    📊 part_of_system: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (part_of_system)
#
#    📊 established_in: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (established_in)
#
#    📊 used_for_setup_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (used_for_setup_of)
#
#    📊 saves_power_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (saves_power_from)
#
#    📊 opposes: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (opposes)
#
#    📊 has_military_wing: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_military_wing)
#
#    📊 existed_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (existed_in)
#
#    📊 member_of: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (member_of)
#
#    📊 married_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (married_to)
#
#    📊 founded: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (founded)
#
#    📊 was_imprisoned_from: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_imprisoned_from)
#
#    📊 was_released_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_released_in)
#
#    📊 associated_with_date: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (associated_with_date)
#
#    📊 was_arrested_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_arrested_on)
#
#    📊 engaged_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (engaged_in)
#
#    📊 was_involved_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_involved_in)
#
#    📊 questioned_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (questioned_as)
#
#    📊 led: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (led)
#
#    📊 is_also_known_as: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_also_known_as)
#
#    📊 has_armed_wing: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_armed_wing)
#
#    📊 enforced: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (enforced)
#
#    📊 violates: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (violates)
#
#    📊 is_called: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_called)
#
#    📊 armed_wing_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (armed_wing_of)
#
#    📊 opposed: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (opposed)
#
#    📊 military_wing_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (military_wing_of)
#
#    📊 carried_out: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (carried_out)
#
#    📊 existed_during: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (existed_during)
#
#    📊 responsible_for: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (responsible_for)
#
#    📊 started_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (started_in)
#
#    📊 ended_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (ended_in)
#
#    📊 sentenced_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (sentenced_on)
#
#    📊 began_on: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (began_on)
#
#    📊 was_turning_point_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (was_turning_point_in)
#
#    📊 targeted: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (targeted)
#
#    📊 drew_attention_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (drew_attention_to)
#
#    📊 is_written_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_written_by)
#
#    📊 is_style_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_style_of)
#
#    📊 has_style_similar_to: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_style_similar_to)
#
#    📊 has_protagonist: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (has_protagonist)
#
#    📊 is_type: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_type)
#
#    📊 features_character: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (features_character)
#
#    📊 explores_theme: 3 edges
#    📦 1 batches
#    [Thread-1] ✅ 3 edges (explores_theme)
#
#    📊 is_authored_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_authored_by)
#
#    📊 is_located_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_located_in)
#
#    📊 is_protagonist_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_protagonist_in)
#
#    📊 is_mother_of: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_mother_of)
#
#    📊 acquired_at: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (acquired_at)
#
#    📊 displayed_above: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (displayed_above)
#
#    📊 observed_for_duration: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (observed_for_duration)
#
#    📊 created_by: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (created_by)
#
#    📊 is_hobby_of: 2 edges
#    📦 1 batches
#    [Thread-1] ✅ 2 edges (is_hobby_of)
#
#    📊 is_character_in: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (is_character_in)
#
#    📊 used_to_create: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (used_to_create)
#
#    📊 performed_using: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (performed_using)
#
#    📊 has_sister: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (has_sister)
#
#    📊 occurs_after: 1 edges
#    📦 1 batches
#    [Thread-1] ✅ 1 edges (occurs_after)
#
#    ✅ Imported 5617 edges
#
# 🔍 VERIFICATION
#    📍 Nodes: 7318
#    🔗 Edges: 28085
#
# ✅ Graph 'play_attend_local' completed
#
# ======================================================================
# 🎉 ALL DONE!
# ======================================================================
